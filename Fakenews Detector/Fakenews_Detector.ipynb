# %%
''' The necessary files can be downloaded from 
    news.csv - https://drive.google.com/u/0/uc?id=1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp&export=download
    glove.6B.50d.txt - https://drive.google.com/file/d/1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp/view
'''

# %%
# Imports
import numpy as np
import pandas as pd
import json
import csv
import random
  
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
  
import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()
  
# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
    sequences1,  padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('glove.6B.50d.txt') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
  
# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
                              input_length=max_length, weights=[
                                  embeddings_matrix],
                              trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2333: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 5s - loss: 0.6472 - accuracy: 0.6096 - val_loss: 0.5730 - val_accuracy: 0.6867 - 5s/epoch - 2ms/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5780 - accuracy: 0.6911 - val_loss: 0.5399 - val_accuracy: 0.7267 - 2s/epoch - 815us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5360 - accuracy: 0.7407 - val_loss: 0.5359 - val_accuracy: 0.7033 - 2s/epoch - 797us/sample
# Epoch 4/50
# 2700/2700 - 2s - loss: 0.4964 - accuracy: 0.7596 - val_loss: 0.5119 - val_accuracy: 0.7433 - 2s/epoch - 794us/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.4455 - accuracy: 0.8007 - val_loss: 0.4946 - val_accuracy: 0.7467 - 2s/epoch - 842us/sample
# Epoch 6/50
# 2700/2700 - 3s - loss: 0.4287 - accuracy: 0.8100 - val_loss: 0.5177 - val_accuracy: 0.7333 - 3s/epoch - 1ms/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3642 - accuracy: 0.8404 - val_loss: 0.5797 - val_accuracy: 0.7100 - 2s/epoch - 800us/sample
# Epoch 8/50
# 2700/2700 - 2s - loss: 0.3405 - accuracy: 0.8507 - val_loss: 0.6207 - val_accuracy: 0.7333 - 2s/epoch - 787us/sample
# Epoch 9/50
# 2700/2700 - 2s - loss: 0.3176 - accuracy: 0.8659 - val_loss: 0.5703 - val_accuracy: 0.7467 - 2s/epoch - 810us/sample
# Epoch 10/50
# 2700/2700 - 2s - loss: 0.2822 - accuracy: 0.8833 - val_loss: 0.5644 - val_accuracy: 0.7233 - 2s/epoch - 798us/sample
# Epoch 11/50
# 2700/2700 - 3s - loss: 0.2650 - accuracy: 0.8863 - val_loss: 0.6056 - val_accuracy: 0.7433 - 3s/epoch - 1ms/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2189 - accuracy: 0.9115 - val_loss: 0.6547 - val_accuracy: 0.7467 - 2s/epoch - 785us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.2119 - accuracy: 0.9148 - val_loss: 0.6348 - val_accuracy: 0.7433 - 2s/epoch - 789us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.2012 - accuracy: 0.9189 - val_loss: 0.7362 - val_accuracy: 0.7267 - 2s/epoch - 793us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1936 - accuracy: 0.9237 - val_loss: 0.6053 - val_accuracy: 0.7433 - 2s/epoch - 798us/sample
# Epoch 16/50
# 2700/2700 - 3s - loss: 0.1546 - accuracy: 0.9381 - val_loss: 0.7978 - val_accuracy: 0.7300 - 3s/epoch - 1ms/sample
# Epoch 17/50
# 2700/2700 - 3s - loss: 0.1571 - accuracy: 0.9400 - val_loss: 0.7281 - val_accuracy: 0.7200 - 3s/epoch - 972us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1747 - accuracy: 0.9311 - val_loss: 0.6953 - val_accuracy: 0.7567 - 2s/epoch - 788us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1355 - accuracy: 0.9537 - val_loss: 0.7120 - val_accuracy: 0.7500 - 2s/epoch - 798us/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.1226 - accuracy: 0.9478 - val_loss: 0.7722 - val_accuracy: 0.7567 - 2s/epoch - 820us/sample
# Epoch 21/50
# 2700/2700 - 2s - loss: 0.1275 - accuracy: 0.9507 - val_loss: 0.8516 - val_accuracy: 0.7367 - 2s/epoch - 884us/sample
# Epoch 22/50
# 2700/2700 - 3s - loss: 0.1340 - accuracy: 0.9481 - val_loss: 0.6868 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1145 - accuracy: 0.9563 - val_loss: 0.7873 - val_accuracy: 0.7300 - 2s/epoch - 782us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1135 - accuracy: 0.9544 - val_loss: 0.9311 - val_accuracy: 0.6967 - 2s/epoch - 804us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.1096 - accuracy: 0.9585 - val_loss: 0.7740 - val_accuracy: 0.7367 - 2s/epoch - 786us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.0928 - accuracy: 0.9641 - val_loss: 0.8845 - val_accuracy: 0.7533 - 2s/epoch - 806us/sample
# Epoch 27/50
# 2700/2700 - 3s - loss: 0.1043 - accuracy: 0.9596 - val_loss: 0.9513 - val_accuracy: 0.7333 - 3s/epoch - 1ms/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.0943 - accuracy: 0.9630 - val_loss: 0.8546 - val_accuracy: 0.7433 - 2s/epoch - 803us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0862 - accuracy: 0.9667 - val_loss: 0.7861 - val_accuracy: 0.7567 - 2s/epoch - 795us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.0840 - accuracy: 0.9693 - val_loss: 0.8398 - val_accuracy: 0.7467 - 2s/epoch - 792us/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.1020 - accuracy: 0.9652 - val_loss: 0.8434 - val_accuracy: 0.7400 - 2s/epoch - 817us/sample
# Epoch 32/50
# 2700/2700 - 3s - loss: 0.0823 - accuracy: 0.9711 - val_loss: 1.0398 - val_accuracy: 0.7433 - 3s/epoch - 1ms/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0772 - accuracy: 0.9719 - val_loss: 0.8512 - val_accuracy: 0.7567 - 2s/epoch - 902us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0832 - accuracy: 0.9733 - val_loss: 0.7394 - val_accuracy: 0.7633 - 2s/epoch - 797us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0720 - accuracy: 0.9748 - val_loss: 0.8309 - val_accuracy: 0.7533 - 2s/epoch - 786us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0657 - accuracy: 0.9770 - val_loss: 0.8416 - val_accuracy: 0.7533 - 2s/epoch - 785us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0821 - accuracy: 0.9711 - val_loss: 0.8446 - val_accuracy: 0.7667 - 2s/epoch - 905us/sample
# Epoch 38/50
# 2700/2700 - 3s - loss: 0.0751 - accuracy: 0.9700 - val_loss: 0.7888 - val_accuracy: 0.7467 - 3s/epoch - 1ms/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0601 - accuracy: 0.9785 - val_loss: 0.9610 - val_accuracy: 0.7600 - 2s/epoch - 811us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0627 - accuracy: 0.9781 - val_loss: 0.8891 - val_accuracy: 0.7767 - 2s/epoch - 792us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0508 - accuracy: 0.9811 - val_loss: 0.9685 - val_accuracy: 0.7633 - 2s/epoch - 796us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0566 - accuracy: 0.9774 - val_loss: 0.8807 - val_accuracy: 0.7633 - 2s/epoch - 832us/sample
# Epoch 43/50
# 2700/2700 - 3s - loss: 0.0578 - accuracy: 0.9774 - val_loss: 0.9240 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 44/50
# 2700/2700 - 2s - loss: 0.0900 - accuracy: 0.9667 - val_loss: 0.8326 - val_accuracy: 0.7533 - 2s/epoch - 800us/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0647 - accuracy: 0.9789 - val_loss: 0.8085 - val_accuracy: 0.7700 - 2s/epoch - 794us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0562 - accuracy: 0.9778 - val_loss: 0.8929 - val_accuracy: 0.7667 - 2s/epoch - 801us/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0583 - accuracy: 0.9789 - val_loss: 0.8782 - val_accuracy: 0.7700 - 2s/epoch - 789us/sample
# Epoch 48/50
# 2700/2700 - 3s - loss: 0.0516 - accuracy: 0.9811 - val_loss: 0.8412 - val_accuracy: 0.7800 - 3s/epoch - 1ms/sample
# Epoch 49/50
# 2700/2700 - 2s - loss: 0.0584 - accuracy: 0.9785 - val_loss: 0.9194 - val_accuracy: 0.7667 - 2s/epoch - 862us/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0730 - accuracy: 0.9737 - val_loss: 0.9089 - val_accuracy: 0.7833 - 2s/epoch - 808us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is True
